# %% [markdown]
# # 0. Study Setup
#
# - 1 Dataset Download [Jump To](#run-1-eeg-dataset-download)
# - 2 Study Setup [Jump To](#run-2-study-setup)

# %% [markdown]
# ## Ref Links
#
# - The Brain Imaging Data Structure (BIDS): https://bids.neuroimaging.io
# - MNE-Python: https://mne.tools/stable/index.html
#
# ## Dependencies
#
# General dependencies:
# - python = 3.11.13
# - numpy = 2.0.2
# - scipy = 1.15.3
# - pandas = 2.2.3
# - matplotlib = 3.10.3
#
# EEG specific dependencies:
# - mne = 1.9.0

# %% [markdown]
# # Imports & Functions

# %% [markdown]
# ## Imports

# %%
# General imports
import os
import sys
import gc
import warnings

from datetime import datetime
from pprint import pprint
import time
import pickle
import random
from collections import Counter

import subprocess
import shutil

# Custom Functions
sys.path.append(os.path.abspath('../Notebooks/Utilities')) 
import cust_utilities as utils

# Maths, Pandas etc
import math
import numpy as np
import pandas as pd
import scipy as sci

# MNE-Python
import mne

# %% [markdown]
# ## Subjects

# %%
# Create a subjects df using the given source participents.tsv

def create_subjects_df(subjects_file, study_name):
     # Read the datset csv file to get selected subjects data
    try:
        temp_subjects_df = pd.read_csv(subjects_file, sep='\t')
    except Exception as e:
        raise IOError(f"Failed to read subjects file '{subjects_file}': {e}")

    # Cater for different format participants.tsv file
    possible_column_names = [
                (['participant_id', 'GROUP', 'AGE', 'GENDER'], ['subject_id', 'pd', 'age', 'gender']),
                (['participant_id', 'Group', 'age', 'sex'], ['subject_id', 'pd', 'age', 'gender']),
                (['participant_id', 'age', 'gender'], ['subject_id', 'age', 'gender'])
            ]
    for cols, new_cols in possible_column_names:
        try:
            subjects_df = temp_subjects_df[cols].copy()
            subjects_df.columns = new_cols
            break
        except KeyError:
            continue
    else:
        raise KeyError("Required columns in subjects file. Found: "f"{temp_subjects_df.columns.tolist()}")
    
    # Add the study_name (slightly redundant)
    subjects_df.insert(0, 'study_name', study_name)
    
    # Derive 'pd' column if not present, based on subject_id containing 'pd'
    if 'pd' not in subjects_df.columns:
        subjects_df['pd'] = subjects_df['subject_id'].apply(lambda x: 1 if 'pd' in str(x).lower() else 0)
        cols = list(subjects_df.columns)
        cols.insert(1, cols.pop(cols.index('pd')))
        subjects_df = subjects_df[cols]

    # Change 'PD', 'Control', 'CTl to yes / no
    if not subjects_df['pd'].isin([0, 1]).all():
        mapping = {'PD': 1, 'pd': 1, 'Control': 0, 'CTL': 0}
        if not subjects_df['pd'].isin(mapping.keys()).all():
            invalid_vals = subjects_df.loc[~subjects_df['pd'].isin(mapping.keys()), 'pd'].unique()
            raise ValueError(f"Invalid values in 'pd' column: {invalid_vals}")
        subjects_df['pd'] = subjects_df['pd'].map(mapping).astype(int)

    return subjects_df

# %% [markdown]
# ## EEG Data

# %%
# Function to get the raw EEG signal data
#

def get_EEG_raw(dataset_path, subject_id):
    """
    Get raw EEG data.

    Parameters
    ----------
    dataset_path : str
    subject_id : str

    Returns
    -------
    EEG_raw : FIF
    """

    # BIDS File Structure
    # dataset_root = 
    # dataset_name = 
    subject = subject_id
    session = ''
    task = 'Rest'
    datatype='eeg'

    # Cater for none or multiple sessions, eg 'ses-01', 'ses-02'
    temp_path = os.path.join(dataset_path, subject)
    subfolders = [f for f in os.listdir(temp_path) if os.path.isdir(os.path.join(temp_path, f))]
    if 'eeg' in subfolders:
        session = ''
    elif any(f.startswith('ses-') for f in subfolders):
        session = sorted([f for f in subfolders if f.startswith('ses-')])
    else:
        raise FileNotFoundError(f"No 'eeg' or session folder found in {temp_path}")
    
    # Cater for 0 or multiple sessions
    # print(f'Test Found: {session}')
    sessions_eeg_raw = []
    if session == '':
        temp_path = os.path.join(dataset_path, subject, datatype)
        temp_file_name = subject + '_task-' + task + '_' + datatype + '.set'
        eeg_lab_file_path = utils.get_file_path(temp_path, temp_file_name)
        try:
            with warnings.catch_warnings(record=True) as w:
                warnings.simplefilter("always")
                eeg_dataset_raw = mne.io.read_raw_eeglab(eeg_lab_file_path, preload=True, verbose=True)
                sessions_eeg_raw.append(eeg_dataset_raw)
                for warn in w:
                    print(f"Warning loading EEG data for subject {subject}: {warn.message}")
                    if eeg_dataset_raw.annotations is not None:
                        print('Removing Annotations')
                        boundary_idx = []
                        for i, desc in enumerate(eeg_dataset_raw.annotations.description):
                            if 'boundary' in desc.lower():
                                boundary_idx.append(i)
                        if boundary_idx:
                            eeg_dataset_raw.annotations.delete(boundary_idx)
        except Exception as e:
            raise ValueError(f"Failed to load EEG data for subject {subject}: {e}")
    else:
        for next_session in session:
            temp_path = os.path.join(dataset_path, subject, next_session, datatype)
            temp_file_name = subject + '_' + next_session + '_task-' + task + '_' + datatype + '.set'
            eeg_lab_file_path = utils.get_file_path(temp_path, temp_file_name)
            try:
                eeg_dataset_raw = mne.io.read_raw_eeglab(eeg_lab_file_path, preload=True, verbose=True)
                sessions_eeg_raw.append(eeg_dataset_raw)
            except Exception as e:
                raise ValueError(f"Failed to load EEG data for subject {subject}: {e}")
    
    return sessions_eeg_raw

# %%
# Function to save EEG data for a given subject
#

def save_EEG_for_subject(eeg_data, folder_path, subject_name, tag, epoched=False, format='fif', verbose=False):

    if epoched:
        subject_results_file = os.path.join(folder_path, f'{subject_name}_{tag}_epo.{format}')
    else:
        subject_results_file = os.path.join(folder_path, f'{subject_name}_{tag}_raw.{format}')

    if format == 'fif':
        eeg_data.save(subject_results_file, overwrite=False, verbose=verbose)
    elif format == 'set':
        mne.export.export_raw(subject_results_file, eeg_data, fmt='eeglab', overwrite=False, verbose=verbose)
    else:
        raise ValueError(f"Unsupported format: {format}")

# %% [markdown]
# # Run 1: EEG Dataset Download

# %%
# Run the shell script in the target EEG directory to download the dataset

#---- Run Parameters --------------------------------
eeg_folder = 'EEG_Datasets_Source_exgithub'
dataset_name = 'ds002778-1.0.2'
script = 'ds002778-1.0.2.sh'
#----------------------------------------------------

# Establish folders
data_folder_path = utils.get_folder_path(eeg_folder)
script_file_path = utils.get_file_path(data_folder_path, script)
results_folder_path = utils.extend_folder_path(data_folder_path, dataset_name, exists_ok=False)

# Run the provided shell script to download the dataset in the target folder
# shutil.copy(script_file_path, results_folder_path)
try:
	result = subprocess.run(['bash', script], cwd=data_folder_path, check=True, capture_output=True, text=True)
	print(result.stdout)
	# os.remove(os.path.join(results_folder_path, script))
except subprocess.CalledProcessError as e:
	print(f"Script failed with error:\n{e.stderr}")

# %% [markdown]
# # Run: 2. Study Setup

# %%
# Execute the Study setup - Run just once for start on a particular study
#

#---- Run Parameters --------------------------------
# Study Specific Details
study_name = 'IOWA_Rest'
dataset_ref = 'ds004584-1.0.0'
source_url = 'https://doi.org/10.18112/openneuro.ds003490.v1.1.0'
source_EEG_format = {'format': 'EEGLab', 
                     'types': ['EEGLab', 'BDF']}

# study_name = 'UNM_Oddball'
# dataset_ref = 'ds003490-1.1.0'
# source_url = 'https://doi.org/10.18112/openneuro.ds003490.v1.1.0'
# source_EEG_format = {'format': 'EEGLab', 
#                      'types': ['EEGLab', 'BDF']}

# study_name = 'UCSD_Rest_New'
# dataset_ref = 'ds002778-1.0.2'
# source_url = 'https://doi.org/10.18112/openneuro.ds002778.v1.0.2'
# source_EEG_format = {'format': 'BDF', 
#                      'types': ['EEGLab', 'BDF']}

#----------------------------------------------------

# EEG Datasets Source Structure - BIDS
eeg_datasets_source_folder = 'EEG_Datasets_Source_exgithub'
subjects_list = 'participants.tsv'

# Folders Structure
EEG_Source_Data = '0_EEG_Source_Data'
EEG_Processing_Results = '1_EEG_Processing_Results'
ML_Training_Results = '2_ML_Training_Results'

# Check for EEG source datasets 
eeg_datasets_folder_path = utils.get_folder_path(eeg_datasets_source_folder)
datasets_list = os.listdir(eeg_datasets_folder_path)
datasets_list = [d for d in datasets_list if d.startswith('ds') and os.path.isdir(os.path.join(eeg_datasets_folder_path, d))]
if dataset_ref not in datasets_list:
    raise ValueError(f"Dataset '{dataset_ref}' not found in list of available datasets: {datasets_list}")
dataset_path = utils.get_folder_path(eeg_datasets_source_folder + '/' + dataset_ref)

# Establish standard folder paths
study_folder_path = utils.make_folder_path('Study_' + study_name, exists_ok=False)
eeg_source_data_path = utils.make_folder_path('Study_' + study_name + '/' + EEG_Source_Data, exists_ok=False)
eeg_processing_results_path = utils.make_folder_path('Study_' + study_name + '/' + EEG_Processing_Results, exists_ok=False)
ml_training_results_path = utils.make_folder_path('Study_' + study_name + '/' + ML_Training_Results, exists_ok=False)

# Save key study info
temp = source_EEG_format['format']
study_info = pd.Series({
    'study_name': study_name, 'dataset_ref': dataset_ref,
    'source_url': source_url, 'source_EEG_format': temp,
    'dataset_path': dataset_path, 
    'eeg_source_data_path': eeg_source_data_path,
    'eeg_processing_results_path': eeg_processing_results_path,
    'ml_training_results_path': ml_training_results_path
    })

# Get the subjects data from the subjects file
subjects_file = utils.get_file_path(dataset_path, subjects_list)
study_subjects_df = create_subjects_df(subjects_file, study_name)

# Save the data files
try:
    study_info.to_pickle(study_folder_path + '/study_inf.pkl', compression='zip')
    study_subjects_df.to_pickle(study_folder_path + '/study_subjects_df.pkl', compression='zip')
except Exception as e:
    print(f"Dataframe pickle save failed: {e}")

# Get Source EEG data for each subject
for idx, subject in study_subjects_df.iterrows():

    subject_id = subject['subject_id']
    print(f'--- Subject: {subject_id} -----------------------------------------')

    EEG_raw_files = get_EEG_raw(dataset_path, subject_id)
    # TODO: How to handle multiple session EEG raw files?
    EEG_raw = EEG_raw_files[0]
    
    save_EEG_for_subject(EEG_raw, eeg_source_data_path, subject_id, tag='source')
    print(EEG_raw)
    print(EEG_raw.info)
# Out:
# --- Subject: sub-001 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-001/eeg/sub-001_task-Rest_eeg.fdt
# Reading 0 ... 140829  =      0.000 ...   281.658 secs...
# Warning loading EEG data for subject sub-001: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-001_task-Rest_eeg.fdt, 63 x 140830 (281.7 s), ~67.8 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-002 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-002/eeg/sub-002_task-Rest_eeg.fdt
# Reading 0 ... 163019  =      0.000 ...   326.038 secs...
# Warning loading EEG data for subject sub-002: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-002_task-Rest_eeg.fdt, 63 x 163020 (326.0 s), ~78.4 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-003 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-003/eeg/sub-003_task-Rest_eeg.fdt
# Reading 0 ... 126179  =      0.000 ...   252.358 secs...
# Warning loading EEG data for subject sub-003: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-003_task-Rest_eeg.fdt, 63 x 126180 (252.4 s), ~60.7 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-004 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-004/eeg/sub-004_task-Rest_eeg.fdt
# Reading 0 ... 131979  =      0.000 ...   263.958 secs...
# Warning loading EEG data for subject sub-004: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-004_task-Rest_eeg.fdt, 63 x 131980 (264.0 s), ~63.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-005 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-005/eeg/sub-005_task-Rest_eeg.fdt
# Reading 0 ... 124769  =      0.000 ...   249.538 secs...
# Warning loading EEG data for subject sub-005: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-005_task-Rest_eeg.fdt, 63 x 124770 (249.5 s), ~60.0 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-006 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-006/eeg/sub-006_task-Rest_eeg.fdt
# Reading 0 ... 131029  =      0.000 ...   262.058 secs...
# Warning loading EEG data for subject sub-006: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-006_task-Rest_eeg.fdt, 63 x 131030 (262.1 s), ~63.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-007 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-007/eeg/sub-007_task-Rest_eeg.fdt
# Reading 0 ... 119909  =      0.000 ...   239.818 secs...
# Warning loading EEG data for subject sub-007: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-007_task-Rest_eeg.fdt, 63 x 119910 (239.8 s), ~57.7 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-008 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-008/eeg/sub-008_task-Rest_eeg.fdt
# Reading 0 ... 117239  =      0.000 ...   234.478 secs...
# Warning loading EEG data for subject sub-008: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-008_task-Rest_eeg.fdt, 63 x 117240 (234.5 s), ~56.4 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-009 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-009/eeg/sub-009_task-Rest_eeg.fdt
# Reading 0 ... 124079  =      0.000 ...   248.158 secs...
# Warning loading EEG data for subject sub-009: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-009_task-Rest_eeg.fdt, 63 x 124080 (248.2 s), ~59.7 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-010 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-010/eeg/sub-010_task-Rest_eeg.fdt
# Reading 0 ... 171349  =      0.000 ...   342.698 secs...
# Warning loading EEG data for subject sub-010: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-010_task-Rest_eeg.fdt, 63 x 171350 (342.7 s), ~82.4 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-011 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-011/eeg/sub-011_task-Rest_eeg.fdt
# Reading 0 ... 78059  =      0.000 ...   156.118 secs...
# Warning loading EEG data for subject sub-011: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-011_task-Rest_eeg.fdt, 63 x 78060 (156.1 s), ~37.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-012 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-012/eeg/sub-012_task-Rest_eeg.fdt
# Reading 0 ... 60279  =      0.000 ...   120.558 secs...
# Warning loading EEG data for subject sub-012: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-012_task-Rest_eeg.fdt, 63 x 60280 (120.6 s), ~29.0 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-013 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-013/eeg/sub-013_task-Rest_eeg.fdt
# Reading 0 ... 61529  =      0.000 ...   123.058 secs...
# Warning loading EEG data for subject sub-013: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-013_task-Rest_eeg.fdt, 63 x 61530 (123.1 s), ~29.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-014 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-014/eeg/sub-014_task-Rest_eeg.fdt
# Reading 0 ... 62799  =      0.000 ...   125.598 secs...
# Warning loading EEG data for subject sub-014: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-014_task-Rest_eeg.fdt, 63 x 62800 (125.6 s), ~30.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-015 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-015/eeg/sub-015_task-Rest_eeg.fdt
# Reading 0 ... 60409  =      0.000 ...   120.818 secs...
# Warning loading EEG data for subject sub-015: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-015_task-Rest_eeg.fdt, 63 x 60410 (120.8 s), ~29.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-016 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-016/eeg/sub-016_task-Rest_eeg.fdt
# Reading 0 ... 60829  =      0.000 ...   121.658 secs...
# Warning loading EEG data for subject sub-016: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-016_task-Rest_eeg.fdt, 63 x 60830 (121.7 s), ~29.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-017 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-017/eeg/sub-017_task-Rest_eeg.fdt
# Reading 0 ... 92609  =      0.000 ...   185.218 secs...
# Warning loading EEG data for subject sub-017: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-017_task-Rest_eeg.fdt, 63 x 92610 (185.2 s), ~44.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-018 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-018/eeg/sub-018_task-Rest_eeg.fdt
# Reading 0 ... 75779  =      0.000 ...   151.558 secs...
# Warning loading EEG data for subject sub-018: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-018_task-Rest_eeg.fdt, 63 x 75780 (151.6 s), ~36.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-019 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-019/eeg/sub-019_task-Rest_eeg.fdt
# Reading 0 ... 93039  =      0.000 ...   186.078 secs...
# Warning loading EEG data for subject sub-019: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-019_task-Rest_eeg.fdt, 63 x 93040 (186.1 s), ~44.8 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-020 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-020/eeg/sub-020_task-Rest_eeg.fdt
# Reading 0 ... 90589  =      0.000 ...   181.178 secs...
# Warning loading EEG data for subject sub-020: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-020_task-Rest_eeg.fdt, 63 x 90590 (181.2 s), ~43.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-021 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-021/eeg/sub-021_task-Rest_eeg.fdt
# Reading 0 ... 79669  =      0.000 ...   159.338 secs...
# Warning loading EEG data for subject sub-021: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-021_task-Rest_eeg.fdt, 63 x 79670 (159.3 s), ~38.4 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-022 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-022/eeg/sub-022_task-Rest_eeg.fdt
# Reading 0 ... 76869  =      0.000 ...   153.738 secs...
# Warning loading EEG data for subject sub-022: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-022_task-Rest_eeg.fdt, 63 x 76870 (153.7 s), ~37.0 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-023 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-023/eeg/sub-023_task-Rest_eeg.fdt
# Reading 0 ... 84549  =      0.000 ...   169.098 secs...
# Warning loading EEG data for subject sub-023: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-023_task-Rest_eeg.fdt, 63 x 84550 (169.1 s), ~40.7 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-024 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-024/eeg/sub-024_task-Rest_eeg.fdt
# Reading 0 ... 75649  =      0.000 ...   151.298 secs...
# Warning loading EEG data for subject sub-024: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-024_task-Rest_eeg.fdt, 63 x 75650 (151.3 s), ~36.4 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-025 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-025/eeg/sub-025_task-Rest_eeg.fdt
# Reading 0 ... 81949  =      0.000 ...   163.898 secs...
# Warning loading EEG data for subject sub-025: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-025_task-Rest_eeg.fdt, 63 x 81950 (163.9 s), ~39.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-026 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-026/eeg/sub-026_task-Rest_eeg.fdt
# Reading 0 ... 71409  =      0.000 ...   142.818 secs...
# Warning loading EEG data for subject sub-026: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-026_task-Rest_eeg.fdt, 63 x 71410 (142.8 s), ~34.4 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-027 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-027/eeg/sub-027_task-Rest_eeg.fdt
# Reading 0 ... 60599  =      0.000 ...   121.198 secs...
# Warning loading EEG data for subject sub-027: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-027_task-Rest_eeg.fdt, 63 x 60600 (121.2 s), ~29.2 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-028 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-028/eeg/sub-028_task-Rest_eeg.fdt
# Reading 0 ... 77299  =      0.000 ...   154.598 secs...
# Warning loading EEG data for subject sub-028: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-028_task-Rest_eeg.fdt, 63 x 77300 (154.6 s), ~37.2 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-029 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-029/eeg/sub-029_task-Rest_eeg.fdt
# Reading 0 ... 101669  =      0.000 ...   203.338 secs...
# Warning loading EEG data for subject sub-029: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-029_task-Rest_eeg.fdt, 63 x 101670 (203.3 s), ~48.9 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-030 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-030/eeg/sub-030_task-Rest_eeg.fdt
# Reading 0 ... 88069  =      0.000 ...   176.138 secs...
# Warning loading EEG data for subject sub-030: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-030_task-Rest_eeg.fdt, 63 x 88070 (176.1 s), ~42.4 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-031 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-031/eeg/sub-031_task-Rest_eeg.fdt
# Reading 0 ... 90669  =      0.000 ...   181.338 secs...
# Warning loading EEG data for subject sub-031: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-031_task-Rest_eeg.fdt, 63 x 90670 (181.3 s), ~43.7 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-032 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-032/eeg/sub-032_task-Rest_eeg.fdt
# Reading 0 ... 75799  =      0.000 ...   151.598 secs...
# Warning loading EEG data for subject sub-032: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-032_task-Rest_eeg.fdt, 63 x 75800 (151.6 s), ~36.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-033 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-033/eeg/sub-033_task-Rest_eeg.fdt
# Reading 0 ... 65679  =      0.000 ...   131.358 secs...
# Warning loading EEG data for subject sub-033: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-033_task-Rest_eeg.fdt, 63 x 65680 (131.4 s), ~31.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-034 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-034/eeg/sub-034_task-Rest_eeg.fdt
# Reading 0 ... 87449  =      0.000 ...   174.898 secs...
# Warning loading EEG data for subject sub-034: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-034_task-Rest_eeg.fdt, 63 x 87450 (174.9 s), ~42.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-035 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-035/eeg/sub-035_task-Rest_eeg.fdt
# Reading 0 ... 101219  =      0.000 ...   202.438 secs...
# Warning loading EEG data for subject sub-035: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-035_task-Rest_eeg.fdt, 63 x 101220 (202.4 s), ~48.7 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-036 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-036/eeg/sub-036_task-Rest_eeg.fdt
# Reading 0 ... 60859  =      0.000 ...   121.718 secs...
# Warning loading EEG data for subject sub-036: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-036_task-Rest_eeg.fdt, 63 x 60860 (121.7 s), ~29.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-037 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-037/eeg/sub-037_task-Rest_eeg.fdt
# Reading 0 ... 64879  =      0.000 ...   129.758 secs...
# Warning loading EEG data for subject sub-037: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-037_task-Rest_eeg.fdt, 63 x 64880 (129.8 s), ~31.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-038 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-038/eeg/sub-038_task-Rest_eeg.fdt
# Reading 0 ... 68019  =      0.000 ...   136.038 secs...
# Warning loading EEG data for subject sub-038: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-038_task-Rest_eeg.fdt, 63 x 68020 (136.0 s), ~32.8 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-039 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-039/eeg/sub-039_task-Rest_eeg.fdt
# Reading 0 ... 82659  =      0.000 ...   165.318 secs...
# Warning loading EEG data for subject sub-039: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-039_task-Rest_eeg.fdt, 63 x 82660 (165.3 s), ~39.8 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-040 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-040/eeg/sub-040_task-Rest_eeg.fdt
# Reading 0 ... 68659  =      0.000 ...   137.318 secs...
# Warning loading EEG data for subject sub-040: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-040_task-Rest_eeg.fdt, 63 x 68660 (137.3 s), ~33.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-041 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-041/eeg/sub-041_task-Rest_eeg.fdt
# Reading 0 ... 75279  =      0.000 ...   150.558 secs...
# Warning loading EEG data for subject sub-041: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-041_task-Rest_eeg.fdt, 63 x 75280 (150.6 s), ~36.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-042 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-042/eeg/sub-042_task-Rest_eeg.fdt
# Reading 0 ... 73329  =      0.000 ...   146.658 secs...
# Warning loading EEG data for subject sub-042: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-042_task-Rest_eeg.fdt, 63 x 73330 (146.7 s), ~35.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-043 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-043/eeg/sub-043_task-Rest_eeg.fdt
# Reading 0 ... 65629  =      0.000 ...   131.258 secs...
# Warning loading EEG data for subject sub-043: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-043_task-Rest_eeg.fdt, 63 x 65630 (131.3 s), ~31.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-044 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-044/eeg/sub-044_task-Rest_eeg.fdt
# Reading 0 ... 69749  =      0.000 ...   139.498 secs...
# Warning loading EEG data for subject sub-044: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-044_task-Rest_eeg.fdt, 63 x 69750 (139.5 s), ~33.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-045 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-045/eeg/sub-045_task-Rest_eeg.fdt
# Reading 0 ... 72669  =      0.000 ...   145.338 secs...
# Warning loading EEG data for subject sub-045: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-045_task-Rest_eeg.fdt, 63 x 72670 (145.3 s), ~35.0 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-046 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-046/eeg/sub-046_task-Rest_eeg.fdt
# Reading 0 ... 65639  =      0.000 ...   131.278 secs...
# Warning loading EEG data for subject sub-046: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-046_task-Rest_eeg.fdt, 63 x 65640 (131.3 s), ~31.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-047 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-047/eeg/sub-047_task-Rest_eeg.fdt
# Reading 0 ... 65469  =      0.000 ...   130.938 secs...
# Warning loading EEG data for subject sub-047: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-047_task-Rest_eeg.fdt, 63 x 65470 (130.9 s), ~31.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-048 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-048/eeg/sub-048_task-Rest_eeg.fdt
# Reading 0 ... 119009  =      0.000 ...   238.018 secs...
# Warning loading EEG data for subject sub-048: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-048_task-Rest_eeg.fdt, 63 x 119010 (238.0 s), ~57.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-049 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-049/eeg/sub-049_task-Rest_eeg.fdt
# Reading 0 ... 60829  =      0.000 ...   121.658 secs...
# Warning loading EEG data for subject sub-049: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-049_task-Rest_eeg.fdt, 64 x 60830 (121.7 s), ~29.8 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-050 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-050/eeg/sub-050_task-Rest_eeg.fdt
# Reading 0 ... 62219  =      0.000 ...   124.438 secs...
# Warning loading EEG data for subject sub-050: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-050_task-Rest_eeg.fdt, 64 x 62220 (124.4 s), ~30.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-051 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-051/eeg/sub-051_task-Rest_eeg.fdt
# Reading 0 ... 62229  =      0.000 ...   124.458 secs...
# Warning loading EEG data for subject sub-051: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-051_task-Rest_eeg.fdt, 63 x 62230 (124.5 s), ~30.0 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-052 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-052/eeg/sub-052_task-Rest_eeg.fdt
# Reading 0 ... 65469  =      0.000 ...   130.938 secs...
# Warning loading EEG data for subject sub-052: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-052_task-Rest_eeg.fdt, 63 x 65470 (130.9 s), ~31.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-053 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-053/eeg/sub-053_task-Rest_eeg.fdt
# Reading 0 ... 63219  =      0.000 ...   126.438 secs...
# Warning loading EEG data for subject sub-053: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-053_task-Rest_eeg.fdt, 63 x 63220 (126.4 s), ~30.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-054 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-054/eeg/sub-054_task-Rest_eeg.fdt
# Reading 0 ... 62499  =      0.000 ...   124.998 secs...
# Warning loading EEG data for subject sub-054: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-054_task-Rest_eeg.fdt, 63 x 62500 (125.0 s), ~30.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-055 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-055/eeg/sub-055_task-Rest_eeg.fdt
# Reading 0 ... 62179  =      0.000 ...   124.358 secs...
# Warning loading EEG data for subject sub-055: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-055_task-Rest_eeg.fdt, 63 x 62180 (124.4 s), ~30.0 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-056 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-056/eeg/sub-056_task-Rest_eeg.fdt
# Reading 0 ... 69589  =      0.000 ...   139.178 secs...
# Warning loading EEG data for subject sub-056: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-056_task-Rest_eeg.fdt, 63 x 69590 (139.2 s), ~33.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-057 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-057/eeg/sub-057_task-Rest_eeg.fdt
# Reading 0 ... 65889  =      0.000 ...   131.778 secs...
# Warning loading EEG data for subject sub-057: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-057_task-Rest_eeg.fdt, 63 x 65890 (131.8 s), ~31.7 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-058 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-058/eeg/sub-058_task-Rest_eeg.fdt
# Reading 0 ... 62559  =      0.000 ...   125.118 secs...
# Warning loading EEG data for subject sub-058: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-058_task-Rest_eeg.fdt, 63 x 62560 (125.1 s), ~30.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
# ...
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-131 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-131/eeg/sub-131_task-Rest_eeg.fdt
# Reading 0 ... 93719  =      0.000 ...   187.438 secs...
# Warning loading EEG data for subject sub-131: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-131_task-Rest_eeg.fdt, 63 x 93720 (187.4 s), ~45.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-132 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-132/eeg/sub-132_task-Rest_eeg.fdt
# Reading 0 ... 88389  =      0.000 ...   176.778 secs...
# Warning loading EEG data for subject sub-132: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-132_task-Rest_eeg.fdt, 63 x 88390 (176.8 s), ~42.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-133 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-133/eeg/sub-133_task-Rest_eeg.fdt
# Reading 0 ... 71449  =      0.000 ...   142.898 secs...
# Warning loading EEG data for subject sub-133: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-133_task-Rest_eeg.fdt, 63 x 71450 (142.9 s), ~34.4 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-134 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-134/eeg/sub-134_task-Rest_eeg.fdt
# Reading 0 ... 72549  =      0.000 ...   145.098 secs...
# Warning loading EEG data for subject sub-134: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-134_task-Rest_eeg.fdt, 63 x 72550 (145.1 s), ~34.9 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-135 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-135/eeg/sub-135_task-Rest_eeg.fdt
# Reading 0 ... 67129  =      0.000 ...   134.258 secs...
# Warning loading EEG data for subject sub-135: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-135_task-Rest_eeg.fdt, 63 x 67130 (134.3 s), ~32.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-136 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-136/eeg/sub-136_task-Rest_eeg.fdt
# Reading 0 ... 72859  =      0.000 ...   145.718 secs...
# Warning loading EEG data for subject sub-136: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-136_task-Rest_eeg.fdt, 63 x 72860 (145.7 s), ~35.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-137 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-137/eeg/sub-137_task-Rest_eeg.fdt
# Reading 0 ... 62959  =      0.000 ...   125.918 secs...
# Warning loading EEG data for subject sub-137: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-137_task-Rest_eeg.fdt, 63 x 62960 (125.9 s), ~30.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-138 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-138/eeg/sub-138_task-Rest_eeg.fdt
# Reading 0 ... 72919  =      0.000 ...   145.838 secs...
# Warning loading EEG data for subject sub-138: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-138_task-Rest_eeg.fdt, 63 x 72920 (145.8 s), ~35.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-139 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-139/eeg/sub-139_task-Rest_eeg.fdt
# Reading 0 ... 92039  =      0.000 ...   184.078 secs...
# Warning loading EEG data for subject sub-139: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-139_task-Rest_eeg.fdt, 63 x 92040 (184.1 s), ~44.3 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-140 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-140/eeg/sub-140_task-Rest_eeg.fdt
# Reading 0 ... 61659  =      0.000 ...   123.318 secs...
# Warning loading EEG data for subject sub-140: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-140_task-Rest_eeg.fdt, 64 x 61660 (123.3 s), ~30.2 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-141 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-141/eeg/sub-141_task-Rest_eeg.fdt
# Reading 0 ... 62499  =      0.000 ...   124.998 secs...
# Warning loading EEG data for subject sub-141: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-141_task-Rest_eeg.fdt, 64 x 62500 (125.0 s), ~30.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-142 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-142/eeg/sub-142_task-Rest_eeg.fdt
# Reading 0 ... 60809  =      0.000 ...   121.618 secs...
# Warning loading EEG data for subject sub-142: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-142_task-Rest_eeg.fdt, 64 x 60810 (121.6 s), ~29.8 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-143 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-143/eeg/sub-143_task-Rest_eeg.fdt
# Reading 0 ... 61109  =      0.000 ...   122.218 secs...
# Warning loading EEG data for subject sub-143: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-143_task-Rest_eeg.fdt, 64 x 61110 (122.2 s), ~29.9 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-144 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-144/eeg/sub-144_task-Rest_eeg.fdt
# Reading 0 ... 60429  =      0.000 ...   120.858 secs...
# Warning loading EEG data for subject sub-144: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-144_task-Rest_eeg.fdt, 64 x 60430 (120.9 s), ~29.6 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-145 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-145/eeg/sub-145_task-Rest_eeg.fdt
# Reading 0 ... 90889  =      0.000 ...   181.778 secs...
# Warning loading EEG data for subject sub-145: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-145_task-Rest_eeg.fdt, 64 x 90890 (181.8 s), ~44.5 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-146 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-146/eeg/sub-146_task-Rest_eeg.fdt
# Reading 0 ... 73709  =      0.000 ...   147.418 secs...
# Warning loading EEG data for subject sub-146: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-146_task-Rest_eeg.fdt, 64 x 73710 (147.4 s), ~36.1 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-147 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-147/eeg/sub-147_task-Rest_eeg.fdt
# Reading 0 ... 62659  =      0.000 ...   125.318 secs...
# Warning loading EEG data for subject sub-147: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-147_task-Rest_eeg.fdt, 64 x 62660 (125.3 s), ~30.7 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-148 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-148/eeg/sub-148_task-Rest_eeg.fdt
# Reading 0 ... 79219  =      0.000 ...   158.438 secs...
# Warning loading EEG data for subject sub-148: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-148_task-Rest_eeg.fdt, 64 x 79220 (158.4 s), ~38.8 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
# --- Subject: sub-149 -----------------------------------------
# Reading /Users/stuartgow/GitHub/EEG_ML_Pipeline/Data/EEG_Datasets_Source_exgithub/ds004584-1.0.0/sub-149/eeg/sub-149_task-Rest_eeg.fdt
# Reading 0 ... 64209  =      0.000 ...   128.418 secs...
# Warning loading EEG data for subject sub-149: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# Removing Annotations
# <RawEEGLAB | sub-149_task-Rest_eeg.fdt, 64 x 64210 (128.4 s), ~31.4 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, Iz, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
# >
